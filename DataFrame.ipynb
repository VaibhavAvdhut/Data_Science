# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavAvdhut/Data_Science/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index= 'A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df['Y']
# Out:
# A   -1.706086
# B    0.166905
# C    0.638787
# D   -0.943406
# E    0.238127
# Name: Y, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.302665 -1.159119
# B -0.134841  0.184502
# C  0.807706  0.329646
# D -0.497104  0.484752
# E -0.116773  1.996652

# %%
df.W
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df.X
# Out:
# A    1.693723
# B    0.390528
# C    0.072960
# D   -0.754070
# E    1.901755
# Name: X, dtype: float64

# %%
type(df['Z'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['new'] = df['Y'] + df ['Z']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  0.302665  1.693723 -1.706086 -1.159119 -2.865205
# B -0.134841  0.390528  0.166905  0.184502  0.351406
# C  0.807706  0.072960  0.638787  0.329646  0.968433
# D -0.497104 -0.754070 -0.943406  0.484752 -0.458655
# E -0.116773  1.901755  0.238127  1.996652  2.234779

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df
# Out:
#           W         X         Y         Z       new
# A  0.302665  1.693723 -1.706086 -1.159119 -2.865205
# B -0.134841  0.390528  0.166905  0.184502  0.351406
# C  0.807706  0.072960  0.638787  0.329646  0.968433
# D -0.497104 -0.754070 -0.943406  0.484752 -0.458655
# E -0.116773  1.901755  0.238127  1.996652  2.234779

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.drop('C',axis=0)
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.loc['A']
# Out:
# W    0.302665
# X    1.693723
# Y   -1.706086
# Z   -1.159119
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W    0.807706
# X    0.072960
# Y    0.638787
# Z    0.329646
# Name: C, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.loc['B','Y']
# Out:
# 0.16690463609281317

# %%
df.loc[['A','D'],['X']]
# Out:
#           X
# A  1.693723
# D -0.754070

# %%
df.loc[['A','D'],['X','Z']]
# Out:
#           X         Z
# A  1.693723 -1.159119
# D -0.754070  0.484752

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True  False  False
# B  False   True   True   True
# C   True   True   True   True
# D  False  False  False   True
# E  False   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723       NaN       NaN
# B       NaN  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D       NaN       NaN       NaN  0.484752
# E       NaN  1.901755  0.238127  1.996652

# %%
df[df['Z']>0]
# Out:
#           W         X         Y         Z
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df[df['Z']>0]['Y']
# Out:
# B    0.166905
# C    0.638787
# D   -0.943406
# E    0.238127
# Name: Y, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652>

# %%
newid = 'CA NY WY OR CO'.split()

# %%
df['States'] = newid

# %%
df
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     CA
# B -0.134841  0.390528  0.166905  0.184502     NY
# C  0.807706  0.072960  0.638787  0.329646     WY
# D -0.497104 -0.754070 -0.943406  0.484752     OR
# E -0.116773  1.901755  0.238127  1.996652     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      0.302665  1.693723 -1.706086 -1.159119
# NY     -0.134841  0.390528  0.166905  0.184502
# WY      0.807706  0.072960  0.638787  0.329646
# OR     -0.497104 -0.754070 -0.943406  0.484752
# CO     -0.116773  1.901755  0.238127  1.996652

# %%
df
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     CA
# B -0.134841  0.390528  0.166905  0.184502     NY
# C  0.807706  0.072960  0.638787  0.329646     WY
# D -0.497104 -0.754070 -0.943406  0.484752     OR
# E -0.116773  1.901755  0.238127  1.996652     CO

# %%
  df.set_index('States',inplace= True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA      0.302665  1.693723 -1.706086 -1.159119
# NY     -0.134841  0.390528  0.166905  0.184502
# WY      0.807706  0.072960  0.638787  0.329646
# OR     -0.497104 -0.754070 -0.943406  0.484752
# CO     -0.116773  1.901755  0.238127  1.996652
